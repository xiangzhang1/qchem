# %%
import qchem
qchem.gui.GUI(safe=False)
# Out:
# Note: Flask dies hard. If 'another program is using your port', you need to pkill -9 python. Needless to say, dangerous.
# Race mode. Both this session and GUI will access same set of variables. Warning: race / conflicts possible.
# computing node {/home/xzhang1/run/master/Yun_ML_QD_trap/Time_benchmarks}
# [2018-06-26 12:20:29,664] ERROR in app: Exception on /compute_node [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1982, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1614, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask_cors/extension.py", line 161, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1517, in handle_user_exception
# ...
