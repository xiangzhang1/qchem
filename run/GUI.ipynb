# %%
import qchem
qchem.gui.GUI(safe=False)
# Out:
# Note: Flask dies hard. If 'another program is using your port', you need to pkill -9 python. Needless to say, dangerous.
# Race mode. Both this session and GUI will access same set of variables. Warning: race / conflicts possible.
# computing node {/home/xzhang1/run/master/PbS_QD/bulk/pbs_bond_nature}
# computing node {/home/xzhang1/run/master/PbS_QD/bulk/pbs_bond_nature/demonstration_1_opt}
# ------------------------------ Overheads ------------------------------
# Gen memory prediction: 3.64651454687 GB used out of 94 GB
# [2018-04-24 10:20:19,479] ERROR in app: Exception on /compute_node [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1982, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1614, in full_dispatch_request
#     rv = self.handle_user_exception(e)
# ...
