# %% [markdown]
# # import numpy, qchem, tensorflow

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from qchem import shared, dynamic, engine, graph

import tensorflow as tf
import keras
import torch

dynamic.global_load()
# Out:
# shared.py: DEBUG = 0
# Using TensorFlow backend.
# global_load called
